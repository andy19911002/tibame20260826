# %% [markdown]
# <a href="https://colab.research.google.com/github/andy19911002/tibame20260826/blob/main/tibame20260826.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 3
print(a)
# Out:
# 3

# %%
print(a+2)
# Out:
# 5

# %% [markdown]
# - 進階知識
#     - Latex Math語法: \ {}
#     - $ area = \frac{1}{1+x} \pi R^3 $
